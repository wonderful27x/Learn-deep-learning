# %%
# %run multi_gpu.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/AI/deep_learn/code/multi_gpu/multi_gpu.py:156
#     151             animator.add(epoch + 1, (d2l.evaluate_accuracy_gpu(
#     152                 lambda x: lenet(x, device_params[0]), test_iter, devices[0]),))
#     153     print(f'测试精度：{animator.Y[0][-1]:.2f}，{timer.avg():.1f}秒/轮，'
#     154           f'在{str(devices)}')
# --> 156 train(num_gpus=1, batch_size=256, lr=0.2)
#
# File ~/AI/deep_learn/code/multi_gpu/multi_gpu.py:148, in train(num_gpus, batch_size, lr)
#     145 for X, y in train_iter:
#     146     # 为单个小批量执行多GPU训练
#     147     train_batch(X, y, device_params, devices, lr)
# --> 148     npx.waitall()
#     149 timer.stop()
#     150  # 在GPU0上评估模型
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py:211, in waitall()
#     202 def waitall():
# ...

# %%
# %run multi_gpu_mxnet.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/AI/deep_learn/code/multi_gpu/multi_gpu_mxnet.py:81
#      77         animator.add(epoch + 1, (evaluate_accuracy_gpus(net, test_iter),))
#      78     print(f'测试精度：{animator.Y[0][-1]:.2f}，{timer.avg():.1f}秒/轮，'
#      79           f'在{str(ctx)}')
# ---> 81 train(num_gpus=1, batch_size=256, lr=0.1)
#
# File ~/AI/deep_learn/code/multi_gpu/multi_gpu_mxnet.py:75, in train(num_gpus, batch_size, lr)
#      73         l.backward()
#      74     trainer.step(batch_size)
# ---> 75 npx.waitall()
#      76 timer.stop()
#      77 animator.add(epoch + 1, (evaluate_accuracy_gpus(net, test_iter),))
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py:211, in waitall()
#     202 def waitall():
#     203     """Wait for all async operations to finish in MXNet.
#     204
# ...
