# %%
# %run softmax_test.py
# Out:
# 60000 10000
# (28, 28, 1)
# (18, 28, 28, 1)
# [2 9 6 0 3 4 4 5 4 8 0 8 9 0 2 2 9 3]
# 3.81 sec
# (32, 1, 64, 64) float32 (32,) int32
# (1, 64, 64) float32

# %%
# %run softmax.py

# %%
# %run mxnet_softmax.py
