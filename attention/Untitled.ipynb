# %%
# %run attention.py
# Out:
# epoch 5, loss 27.660433
# odict_keys(['nwkernelregression39_w'])
# weight: [0.00350114]
# [2. 2. 3. 3.]

# %%
# %run attention_f.py
# Out:
# 加性注意力
# W_q.weight:  (8, 20)
# W_k.weight:  (8, 2)
# w_v.weight:  (1, 8)
# attention_value shape:  (2, 1, 4)
# [[[ 2.  3.  4.  5.]]
#
#  [[10. 11. 12. 13.]]]
# attention_weights shape:
#  (2, 1, 10)
# [[[0.5        0.5        0.         0.         0.         0.
#    0.         0.         0.         0.        ]]
#
#  [[0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667
#    0.         0.         0.         0.        ]]]
# 缩放点积注意力
# [[[ 2.  3.  4.  5.]]
#
#  [[10. 11. 12. 13.]]]
