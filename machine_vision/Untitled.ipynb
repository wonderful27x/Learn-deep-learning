# %%
# %run fine-tuning.py
# Out:
# loss 0.267, train acc 0.912, test acc 0.935
# 15.0 examples/sec on [cpu(0)]

# %%
# %run target_detect.py
# Out:
# read 1000 training examples
# read 100 validation examples
# 2
# (32, 3, 256, 256) (32, 1, 5)

# %%
# %run ssd.py
# Out:
# (2, 64, 32, 32)
# (1, 4096, 4)
# 测试TinySSD
# output anchors: (1, 5444, 4)
# output class preds: (32, 5444, 2)
# output bbox preds: (32, 21776)
# read 1000 training examples
# read 100 validation examples
# (1, 4096, 4)
# class err 3.55e-03, bbox mae 3.80e-03
# 2426.7 examples/sec on cpu(0)
# predict box:  [array([290.7511 , 370.49362, 501.29944, 558.5226 ])]
# predict box:  [array([257.22934, 318.97122, 465.26047, 520.26556])]
# predict box:  [array([343.5737 , 417.24344, 557.23865, 603.9323 ])]
# predict box:  [array([ -25.155762,  367.13672 , 1305.6084  , 1080.9678  ])]
# predict box:  [array([ 571.4285 ,   27.65744, 1451.1787 ,  474.34506])]
# predict box:  [array([428.43393, 424.31683, 615.27185, 659.55023])]
# predict box:  [array([701.8477 , 579.6114 , 921.36444, 782.32526])]
# predict box:  [array([ 313.87878, -294.0415 ,  796.19055, 1086.879  ])]
# predict box:  [array([315.41068, 315.52026, 537.1408 , 627.89294])]
# ...

# %%
# %run semantic_segmentation.py
# Out:
# loss 2.267, train acc 0.645, test acc 0.708
# 5.0 examples/sec on [cpu(0)]
