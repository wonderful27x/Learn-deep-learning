# %%
# %run conv_net.py
# Out:
# loss0.472, train acc 0.823, test acc 0.825
# 19360.6 examples/sec oncpu(0)

# %%
# %run AlexNet.py
# Out:
# loss0.357, train acc 0.870, test acc 0.880
# 64.2 examples/sec oncpu(0)

# %%
# %run ResNet.py
# Out:
# (4, 3, 6, 6)
# (4, 6, 3, 3)
# conv153 output shape:	 (1, 64, 112, 112)
# batchnorm92 output shape:	 (1, 64, 112, 112)
# relu4 output shape:	 (1, 64, 112, 112)
# pool28 output shape:	 (1, 64, 56, 56)
# sequential30 output shape:	 (1, 64, 56, 56)
# sequential31 output shape:	 (1, 128, 28, 28)
# sequential32 output shape:	 (1, 256, 14, 14)
# sequential33 output shape:	 (1, 512, 7, 7)
# pool29 output shape:	 (1, 512, 1, 1)
# dense31 output shape:	 (1, 10)
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# File ~/AI/deep_learn/code/conv_net/ResNet.py:136
#     131 train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=96)
#     133 # train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
#     134
#     135 # 预测
# --> 136 predict_ch3(net, test_iter)
#
# File ~/AI/deep_learn/code/conv_net/ResNet.py:126, in predict_ch3(net, test_iter, n)
# ...

# %%
# %run DenseNet.py
# Out:
# (4, 23, 8, 8)
# (4, 10, 4, 4)
# (256, 10)
