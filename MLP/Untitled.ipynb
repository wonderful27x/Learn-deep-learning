# %%
# %run mlp_learn.py

# %%
# %run mlp.py

# %%
# %run mxnet_mlp.py

# %%
# %run house_predict.py
# Out:
# (1460, 81)
# (1459, 80)
#    Id  MSSubClass MSZoning  LotFrontage SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0       WD        Normal     208500
# 1   2          20       RL         80.0       WD        Normal     181500
# 2   3          60       RL         68.0       WD        Normal     223500
# 3   4          70       RL         60.0       WD       Abnorml     140000
# (2919, 330)
# K折交叉训练...
# 折1, 训练log rmse0.140104,验证log rmse0.161508
# 折2, 训练log rmse0.192376,验证log rmse0.238211
# 折3, 训练log rmse0.089359,验证log rmse0.181217
# 折4, 训练log rmse0.174084,验证log rmse0.200348
# 折5, 训练log rmse0.128296,验证log rmse0.201138
# 5-折验证：平均训练log rmse: 0.144844, 平均验证log rmse: 0.196484
# 整体训练...
# 训练log rmse: 0.085215
